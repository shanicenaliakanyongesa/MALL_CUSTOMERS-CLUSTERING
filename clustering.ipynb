# %%
import pandas
data=pandas.read_csv('EastWestAirlines.csv')
data
# Out:
#       Balance  QualMiles  BonusMiles  BonusTrans  FlightMiles  FlightTrans  \
# 0       28143          0         174           1            0            0
# 1       19244          0         215           2            0            0
# 2       41354          0        4123           4            0            0
# 3       14776          0         500           1            0            0
# 4       97752          0       43300          26         2077            4
# ...       ...        ...         ...         ...          ...          ...
# 3994    18476          0        8525           4          200            1
# 3995    64385          0         981           5            0            0
# 3996    73597          0       25447           8            0            0
# 3997    54899          0         500           1          500            1
# 3998     3016          0           0           0            0            0
#
#       DaysSinceEnroll
# 0                7000
# 1                6968
# 2                7034
# 3                6952
# 4                6935
# ...               ...
# 3994             1403
# 3995             1395
# 3996             1402
# 3997             1401
# 3998             1398
#
# [3999 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Balance            0
# QualMiles          0
# BonusMiles         0
# BonusTrans         0
# FlightMiles        0
# FlightTrans        0
# DaysSinceEnroll    0
# dtype: int64

# %%
array=data.values
x=array[:,4:7]

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=10, random_state=42)
model.fit(x)
# Out:
# KMeans(n_clusters=10, random_state=42)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Balance          3999 non-null   int64
#  1   QualMiles        3999 non-null   int64
#  2   BonusMiles       3999 non-null   int64
#  3   BonusTrans       3999 non-null   int64
#  4   FlightMiles      3999 non-null   int64
#  5   FlightTrans      3999 non-null   int64
#  6   DaysSinceEnroll  3999 non-null   int64
# dtypes: int64(7)
# memory usage: 218.8 KB

# %%
# Lets see the 10 Clusters Kmeans created.
means = model.cluster_centers_
clusters = pandas.DataFrame(means, columns = ['FlightMiles', 'FlightTrans', 'DaysSinceEnroll'])
clusters
# Out:
#     FlightMiles  FlightTrans  DaysSinceEnroll
# 0    142.759763     0.521893      4413.641420
# 1    118.298122     0.481221      1425.549296
# 2   3607.056338    11.352113      7099.619718
# 3   3523.925532     9.361702      2166.829787
# 4   9342.923077    21.205128      4344.256410
# 5    167.841146     0.626302      5960.665365
# 6   2386.250000     6.858333      4765.216667
# 7    137.670951     0.508997      2913.440874
# 8    212.418605     0.769767      7505.500000
# 9  26458.500000    49.000000      2602.000000

# %%
# Let see who is in group 2
data['no']  = model.labels_   # get every record group number
cluster5 =  data[data['no'] == 5]
cluster5
# Out:
#       Balance  QualMiles  BonusMiles  BonusTrans  FlightMiles  FlightTrans  \
# 128     48333          0       10123          14            0            0
# 129    142175          0       37461          22            0            0
# 130     17469          0           0           0            0            0
# 136    129298          0       29099          15            0            0
# 137    103302          0       53552          22          700            3
# ...       ...        ...         ...         ...          ...          ...
# 1414   130364          0       62083          15          250            1
# 1415    15592       4924       37173          13            0            0
# 1416    25404          0        2125           7          500            1
# 1418    32313          0       29188          27            0            0
# 1419   168897          0       37451          24          400            2
#
#       DaysSinceEnroll  no
# 128              6737   5
# 129              6732   5
# 130              6730   5
# 136              6722   5
# 137              6718   5
# ...               ...  ..
# 1414             5213   5
# 1415             5209   5
# 1416             5203   5
# 1418             5397   5
# 1419             5189   5
#
# [768 rows x 8 columns]

# %%
data[data['no'] == 5].to_csv('Cluster5.csv')
